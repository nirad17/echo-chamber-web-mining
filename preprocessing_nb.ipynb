# %%
import pandas as pd
import re
import string
import demoji
import contractions
from nltk.corpus import stopwords
from nltk.tokenize import TweetTokenizer
from nltk.stem import PorterStemmer
from nltk import pos_tag, ne_chunk
from nltk.tree import Tree

# %%
# Load your dataset
df = pd.read_csv("twitter_sentiment_data.csv")

# %%
# change the column names to lowercase and remove all white spaces
df.columns = df.columns.str.lower().str.replace(' ', '')
df.head()
# Out:
#    sentiment                                            message
# 0         -1  @tiniebeany climate change is an interesting h...  \
# 1          1  RT @NatGeoChannel: Watch #BeforeTheFlood right...
# 2          1  Fabulous! Leonardo #DiCaprio's film on #climat...
# 3          1  RT @Mick_Fanning: Just watched this amazing do...
# 4          2  RT @cnalive: Pranita Biswasi, a Lutheran from ...
#
#               tweetid
# 0  792927353886371840
# 1  793124211518832641
# 2  793124402388832256
# 3  793124635873275904
# 4  793125156185137153

# %%
# Step 1: Remove Duplicates
df = df.drop_duplicates(subset=['message'])

# %%
# Step 2: Handling Retweets
df['is_retweet'] = df['message'].apply(lambda x: x.startswith('RT'))
#add retweet_username column
df['retweet_username'] = df['message'].apply(lambda x: re.findall(r'RT @\w+:', x))
# remove RT from message
df['message'] = df['message'].apply(lambda x: re.sub(r'RT', '', x))
#hande the case @username: make a new column for the username
df['username'] = df['message'].apply(lambda x: re.findall(r'@\w+', x))
#remove the username from the message
df['message'] = df['message'].apply(lambda x: re.sub(r'@\w+', '', x))

# %%
df.head()
# Out:
#    sentiment                                            message
# 0         -1   climate change is an interesting hustle as it...  \
# 1          1   : Watch #BeforeTheFlood right here, as  trave...
# 2          1  Fabulous! Leonardo #DiCaprio's film on #climat...
# 3          1   : Just watched this amazing documentary by le...
# 4          2   : Pranita Biswasi, a Lutheran from Odisha, gi...
#
#               tweetid  is_retweet      retweet_username
# 0  792927353886371840       False                    []  \
# 1  793124211518832641        True  [RT @NatGeoChannel:]
# 2  793124402388832256       False                    []
# 3  793124635873275904        True   [RT @Mick_Fanning:]
# 4  793125156185137153        True        [RT @cnalive:]
#
#                          username
# 0                   [@tiniebeany]
# 1  [@NatGeoChannel, @LeoDiCaprio]
# 2                      [@youtube]
# 3                 [@Mick_Fanning]
# 4                      [@cnalive]

# %%
# Step 3: Text Cleaning
def clean_text(text):
    # Handle links separately
    links = re.findall(r'http\S+', text)
    text = re.sub(r'http\S+', '', text)
    # Remove emojis
    text = demoji.replace_with_desc(text, sep=' ')
    # Remove special characters and numbers
    text = re.sub('[^A-Za-z]+', ' ', text)
    # Convert to lowercase
    text = text.lower().strip()
    return text, links

df[['cleaned_message', 'links']] = df['message'].apply(clean_text).apply(pd.Series)
df.head()
# Out:
#    sentiment                                            message
# 0         -1   climate change is an interesting hustle as it...  \
# 1          1   : Watch #BeforeTheFlood right here, as  trave...
# 2          1  Fabulous! Leonardo #DiCaprio's film on #climat...
# 3          1   : Just watched this amazing documentary by le...
# 4          2   : Pranita Biswasi, a Lutheran from Odisha, gi...
#
#               tweetid  is_retweet      retweet_username
# 0  792927353886371840       False                    []  \
# 1  793124211518832641        True  [RT @NatGeoChannel:]
# 2  793124402388832256       False                    []
# 3  793124635873275904        True   [RT @Mick_Fanning:]
# 4  793125156185137153        True        [RT @cnalive:]
#
#                          username
# 0                   [@tiniebeany]  \
# 1  [@NatGeoChannel, @LeoDiCaprio]
# 2                      [@youtube]
# 3                 [@Mick_Fanning]
# 4                      [@cnalive]
#
#                                      cleaned_message
# 0  climate change is an interesting hustle as it ...  \
# 1  watch beforetheflood right here as travels the...
# 2  fabulous leonardo dicaprio s film on climate c...
# 3  just watched this amazing documentary by leona...
# 4  pranita biswasi a lutheran from odisha gives t...
#
#                        links
# 0                         []
# 1  [https://t.co/LkDehj3tNn]
# 2  [https://t.co/7rV6BrmxjW]
# 3  [https://t.co/kNSTE8K8im]
# 4                         []

# %%
# Step 4: Expand Contractions
df['expanded_message'] = df['cleaned_message'].apply(lambda x: contractions.fix(x))

# %%
# Step 5: Advanced Tokenization
tokenizer = TweetTokenizer(preserve_case=False, strip_handles=True, reduce_len=True)
df['tokenized_message'] = df['expanded_message'].apply(tokenizer.tokenize)

# %%
# Step 6: Remove Stopwords and Punctuation
stop_words = set(stopwords.words('english'))
punctuation = set(string.punctuation)
df['tokenized_message'] = df['tokenized_message'].apply(lambda x: [word for word in x if word not in stop_words and word not in punctuation])

# %%
from nltk.stem import PorterStemmer, WordNetLemmatizer
from nltk.corpus import stopwords
import nltk
nltk.download('wordnet')

#  Stemming
stemmer = PorterStemmer()
df['stemmed_message'] = df['tokenized_message'].apply(lambda x: [stemmer.stem(word) for word in x])

# Lemmatization
lemmatizer = WordNetLemmatizer()
df['lemmatized_message'] = df['tokenized_message'].apply(lambda x: [lemmatizer.lemmatize(word) for word in x])
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\nirad\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
# Step 7: Part-of-Speech Tagging and Named Entity Recognition
import nltk
nltk.download('averaged_perceptron_tagger')

def preprocess_pos_ner(tokens):
    pos_tags = pos_tag(tokens)
    # Replace named entities with a common tag
    pos_tags = [(tag[0], 'NE' if tag[1] == 'NNP' else tag[1]) for tag in pos_tags]
    return pos_tags

df['pos_tags'] = df['tokenized_message'].apply(preprocess_pos_ner)
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\nirad\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %%
# Display the preprocessed dataframe
df.head()
# Out:
#    sentiment                                            message
# 0         -1   climate change is an interesting hustle as it...  \
# 1          1   : Watch #BeforeTheFlood right here, as  trave...
# 2          1  Fabulous! Leonardo #DiCaprio's film on #climat...
# 3          1   : Just watched this amazing documentary by le...
# 4          2   : Pranita Biswasi, a Lutheran from Odisha, gi...
#
#               tweetid  is_retweet      retweet_username
# 0  792927353886371840       False                    []  \
# 1  793124211518832641        True  [RT @NatGeoChannel:]
# 2  793124402388832256       False                    []
# 3  793124635873275904        True   [RT @Mick_Fanning:]
# 4  793125156185137153        True        [RT @cnalive:]
#
#                          username
# 0                   [@tiniebeany]  \
# 1  [@NatGeoChannel, @LeoDiCaprio]
# 2                      [@youtube]
# 3                 [@Mick_Fanning]
# 4                      [@cnalive]
#
#                                      cleaned_message
# 0  climate change is an interesting hustle as it ...  \
# 1  watch beforetheflood right here as travels the...
# 2  fabulous leonardo dicaprio s film on climate c...
# 3  just watched this amazing documentary by leona...
# 4  pranita biswasi a lutheran from odisha gives t...
#
#                        links
# 0                         []  \
# 1  [https://t.co/LkDehj3tNn]
# 2  [https://t.co/7rV6BrmxjW]
# 3  [https://t.co/kNSTE8K8im]
# 4                         []
#
#                                     expanded_message
# 0  climate change is an interesting hustle as it ...  \
# 1  watch beforetheflood right here as travels the...
# 2  fabulous leonardo dicaprio s film on climate c...
# 3  just watched this amazing documentary by leona...
# 4  pranita biswasi a lutheran from odisha gives t...
#
#                                    tokenized_message
# 0  [climate, change, interesting, hustle, global,...  \
# 1  [watch, beforetheflood, right, travels, world,...
# 2  [fabulous, leonardo, dicaprio, film, climate, ...
# 3  [watched, amazing, documentary, leonardodicapr...
# 4  [pranita, biswasi, lutheran, odisha, gives, te...
#
#                                      stemmed_message
# 0  [climat, chang, interest, hustl, global, warm,...  \
# 1  [watch, beforetheflood, right, travel, world, ...
# 2  [fabul, leonardo, dicaprio, film, climat, chan...
# 3  [watch, amaz, documentari, leonardodicaprio, c...
# 4  [pranita, biswasi, lutheran, odisha, give, tes...
#
#                                   lemmatized_message
# 0  [climate, change, interesting, hustle, global,...  \
# 1  [watch, beforetheflood, right, travel, world, ...
# 2  [fabulous, leonardo, dicaprio, film, climate, ...
# 3  [watched, amazing, documentary, leonardodicapr...
# 4  [pranita, biswasi, lutheran, odisha, give, tes...
#
#                                             pos_tags
# 0  [(climate, NN), (change, NN), (interesting, VB...
# 1  [(watch, NN), (beforetheflood, NN), (right, RB...
# 2  [(fabulous, JJ), (leonardo, NN), (dicaprio, NN...
# 3  [(watched, VBN), (amazing, JJ), (documentary, ...
# 4  [(pranita, JJ), (biswasi, NN), (lutheran, NN),...

# %%
df.to_csv('preprocessed_twitter_sentiment_data.csv', index=False)
